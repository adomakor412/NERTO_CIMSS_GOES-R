# %% [markdown]
# # Generate SHARKFINS-artifact Full Disk images of GOES-R NetCDF files and upload them to GitLab database.

# %% [markdown]
# https://gitlab.com/adomakor412/goes-r_fd_image

# %%
import sys
from PIL import Image
from netCDF4 import Dataset
from datetime import datetime, timedelta, date
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.basemap import Basemap
from pathlib import Path
from subprocess import Popen
import itertools
from pyproj import Proj
import pyproj
import xarray as xr
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from pyresample import image, geometry
import metpy
import seaborn as sns
sns.set(style="darkgrid")
import pandas as pd
import statsmodels.api as sm
import os
import os.path as op
import glob
from convertdate import gregorian, ordinal
from multiprocessing import Pool
import re

import warnings
#warnings.filterwarnings('ignore')

import logging
logger = logging.getLogger()

# %% [markdown]
# ## Paths

# %%
store = '/scratch/radomako/artifacts/'
sharkfins_FD_NC = '/scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/'
#caterpillar_FD_NC = '/scratch/gops/amqpfind/adomako_data/l1b_imagery_caterpillar_track/'

# %% [markdown]
# ## Functions for unfiltered cloud mask

# %%
def Rad2BT(rad, planck_fk1, planck_fk2, planck_bc1, planck_bc2):
    """Radiances to Brightness Temprature (using black body equation)"""
    
    planck_fk1 = abs(planck_fk1)
    planck_fk2 = abs(planck_fk2)
    planck_bc1 = abs(planck_bc1)
    planck_bc2 = abs(planck_bc2)
    
    invRad = np.array(abs(rad))**(-1)
    arg = (invRad*planck_fk1) + 1.0
    T = (- planck_bc1+(planck_fk2 * (np.log(arg)**(-1))) )*(1/planck_bc2)
    return T



def download(url,toPath, saveName):
    cmd = [ 'wget ' + url +' -P ' + toPath +' -O '+ saveName]#if re.search('C07',url)
    #print(cmd)
    pid = Popen(cmd, shell=True)
    pid.communicate()
    return

# %% [markdown]
# ## Load data

# %%
# Sat = [16,17]
# #band = range(7,17)
# year = [2021]
# month = list(range(1,3))
# day = list(range(1,32))
# hour = list(range(1,24))

# %%
# search = list(itertools.product(Sat,\
#         #band,\
#         year,\
#         month,\
#         day,\
#         hour))

# %% [markdown]
# ## Execution

# %%
def execute(artifact,storage):
    filelog = open('sharkfin.txt','w')

    #for SS, bb, yyyy, mm, dd, hr in chunk:
    #SS, bb, yyyy, mm, dd, hr = chunk
#     SS, yyyy, mm, dd, hr = chunk
#     bb = band
#     SS, bb, yyyy, mm, dd, hr = \
#         str(SS).zfill(2),\
#         str(bb).zfill(2),\
#         str(yyyy).zfill(4),\
#         str(mm).zfill(2),\
#         str(dd).zfill(2),\
#         str(hr).zfill(2)



#     #Create Directories    
#     cond2 = os.path.exists(f'{storage}/{yyyy}')
#     cond3 = os.path.exists(f'{storage}/{yyyy}/{DDD}')
#     cond4 = os.path.exists(f'{storage}/{yyyy}/{DDD}/{bb}')

#     if not cond2:
#         #KEEP CONDITION AS A DYNAMIC F-STRING OTHERWISE VARIABLE IS STATIC, utilize loop
#         #make di
#             #Create Directoriesrectory per year
#         cmd = [f'mkdir {storage}/{yyyy}']
#         pid = Popen(cmd, shell=True) 
#         pid.communicate()

#     if not cond3:
#         #KEEP CONDITION AS A DYNAMIC F-STRING OTHERWISE VARIABLE IS STATIC, utilize loop
#         #make directory per year
#         cmd = [f'mkdir {storage}/{yyyy}/{DDD}']
#         pid = Popen(cmd, shell=True) 
#         pid.communicate()
        
#     if not cond4:
#         #KEEP CONDITION AS A DYNAMIC F-STRING OTHERWISE VARIABLE IS STATIC, utilize loop
#         #make directory per year
#         cmd = [f'mkdir {storage}/{yyyy}/{DDD}/{bb}']
#         pid = Popen(cmd, shell=True) 
#         pid.communicate()

    try:
        #Not a cd command, use absolute path
        #netcdf = glob.glob(f'~/arcdata/goes/grb/goes{SS}/{yyyy}/{yyyy}_{mm}_{dd}_{DDD}/abi/L1b/RadF/')
        netcdf = []
        for CH in range(7,17):
            channel = str(CH).zfill(2)
            myGlob = glob.glob(op.join(artifact,'*C{}*.nc'.format(channel)))
            netcdf += myGlob

        print(netcdf, file=filelog)

        for file in netcdf:
            print(file)
            
            downsize_x = 224
            downsize_y = 224
            my_dpi = 192
            
            naming = f'{os.path.basename(os.path.normpath(file[:-3]))}_UTC_{downsize_x}x{downsize_y}_BW.jpg'
            savePath = op.join(store,storage)
        
            if os.path.isfile(op.join(savePath,naming)):
                continue
                
            i = file.find('_s',-55)#+2
            yyyy = file[i+2: i+6]
            
            DDD = file[i+6: i+9]
            HH = file[i+9: i+11]
            MM = file[i+11: i+13]
            ss = file[i+13: i+15]
            SS = file[i-2: i]
            bb = file[i-6: i-4]
            mm = str(ordinal.to_gregorian(int(yyyy),int(DDD))[1]).zfill(2)
            dd = str(ordinal.to_gregorian(int(yyyy),int(DDD))[2]).zfill(2)
            
            GOES_R = xr.open_dataset(file)
            GOES_image = GOES_R['Rad']

            planck_fk1 = float(GOES_R['planck_fk1'].data)
            planck_fk2 = float(GOES_R['planck_fk2'].data) 
            planck_bc1 = float(GOES_R['planck_bc1'].data)                       
            planck_bc2 = float(GOES_R['planck_bc2'].data)
            #Need not convert projection: using full image, no pyproj interpolation of region of interest
            Kelvin_GOES_image = Rad2BT(GOES_image, planck_fk1, planck_fk2, planck_bc1, planck_bc2)
            
            '''
            https://www.infobyip.com/detectmonitordpi.php
            stackoverflow.com/questions/13714454/specifying-and-saving-a-figure-with-exact-size-in-pixels
            '''
            plt.figure(figsize=(downsize_x/my_dpi, downsize_y/my_dpi), dpi=my_dpi)
            plt.grid(None)
            plt.axis('off')
#             title = f'Brightness Temperature in Kelvin \n Full Disk GOES-{SS} Image Band{bb}'
#             ttl = plt.title(f"{title}\n Date {mm}-{dd}, Year {yyyy}, \n Day {DDD}, Time {HH}:{MM}:{ss}",\
#                        fontsize="x-large", fontweight='bold', pad = 6.0)
#             ttl.set_position([.5, 1.05])
            fig1=plt.imshow(Kelvin_GOES_image, cmap='Greys', vmin=180,vmax=300)
            arr = fig1.get_array()
#             cbar = plt.colorbar()
#             cbar.ax.set_ylabel('Kelvin')

            saveName = op.join(savePath,naming)
            if not os.path.isfile(saveName):
                #plt.imsave( op.join(savePath,naming), arr=arr, cmap = 'gray')
                fig1.figure.savefig(saveName)
                cmd = [ 'convert '+ saveName +' -colorspace Gray '+ saveName]#if re.search('C07',url)
                pid = Popen(cmd, shell=True)
                pid.communicate()
                
            naming = f'{os.path.basename(os.path.normpath(file[:-3]))}_UTC_{downsize_x}x{downsize_y}.jpg'

            fig1 = plt.imshow(Kelvin_GOES_image, vmin=180, vmax=300, cmap = 'plasma')
            arr = fig1.get_array()

            plt.grid(None) #Call after the imshow, redraws
            plt.axis('off')#Call after the imshow, redraws; "layer" to previous drawing

            if not os.path.isfile(op.join(storage,naming)):
                fig1.figure.savefig(op.join(savePath,naming))
            plt.close('all')
            GOES_R.close()

    except ValueError as e:
        print('THERE IS AN ERROR')
        print('\n', file = filelog)
        print(file, file = filelog)
        print(e, file = filelog)
        print('\n', file = filelog)

    filelog.close()
    return

# %%
#artifactList = [caterpillar_FD_NC]
artifactList = [sharkfins_FD_NC]

for artifact in artifactList:
    if artifact == sharkfins_FD_NC:
        storage = 'sharkfin'
    else:
        storage = 'caterpillar'
    execute(artifact,storage)
# Out:
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C07_G17_s20193491650341_e20193491659419_c20193491659465.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C07_G17_s20193600950342_e20193600959420_c20193600959460.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C07_G16_s20193621310223_e20193621319542_c20193621320000.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C07_G17_s20200331510321_e20200331519399_c20200331519442.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C07_G17_s20200392010321_e20200392019399_c20200392019444.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C07_G16_s20200481650201_e20200481659520_c20200481659583.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C07_G17_s20200991840320_e20200991849399_c20200991849444.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C07_G16_s20201232210147_e20201232219467_c20201232219524.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C07_G17_s20201270520319_e20201270529397_c20201270529443.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C07_G16_s20202551850193_e20202551859513_c20202551859570.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C07_G16_s20202562220189_e20202562229508_c20202562229558.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C07_G17_s20202740320319_e20202740329397_c20202740329443.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C07_G17_s20202790800319_e20202790809397_c20202790809443.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C07_G16_s20202870530178_e20202870539497_c20202870539549.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C07_G16_s20203012120193_e20203012129512_c20203012129568.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C08_G16_s20193612230219_e20193612239527_c20193612239589.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C08_G16_s20193642120218_e20193642129526_c20193642129592.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C08_G16_s20200060000211_e20200060009518_c20200060009588.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C08_G17_s20200181430321_e20200181439388_c20200181439445.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C08_G17_s20200331510321_e20200331519388_c20200331519439.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C08_G17_s20201282100319_e20201282109385_c20201282109446.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C08_G16_s20201331340149_e20201331349457_c20201331349521.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C08_G16_s20202591320175_e20202591329483_c20202591329551.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C08_G17_s20202692050321_e20202692059388_c20202692059446.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C08_G17_s20202790800319_e20202790809385_c20202790809441.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C08_G17_s20202791710321_e20202791719387_c20202791719440.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C08_G17_s20202841320321_e20202841329387_c20202841329442.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C08_G17_s20202841410321_e20202841419387_c20202841419441.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C08_G16_s20203042230186_e20203042239494_c20203042239567.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C08_G16_s20210192330191_e20210192339499_c20210192339569.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C08_G17_s20210242040321_e20210242049388_c20210242049449.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C09_G17_s20200502120310_e20200502129384_c20200502129445.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C09_G17_s20200961400321_e20200961409393_c20200961409436.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C09_G17_s20201511420321_e20201511429393_c20201511429439.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C09_G17_s20201801720321_e20201801729393_c20201801729446.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C09_G16_s20202591320175_e20202591329489_c20202591329567.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C09_G16_s20202641250188_e20202641259502_c20202641259590.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C09_G17_s20202772140318_e20202772149391_c20202772149426.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C09_G17_s20202791710321_e20202791719393_c20202791719437.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C09_G17_s20210330010319_e20210330019391_c20210330019430.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C10_G17_s20193491650341_e20193491659419_c20193491659462.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C10_G17_s20193501530341_e20193501539420_c20193501539464.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C10_G16_s20200080750209_e20200080759528_c20200080759575.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C10_G16_s20200170510195_e20200170519514_c20200170519570.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C10_G17_s20200250710319_e20200250719398_c20200250719432.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C10_G17_s20200342150319_e20200342159397_c20200342159430.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C10_G17_s20200391840321_e20200391849399_c20200391849430.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C10_G17_s20200400050319_e20200400059396_c20200400059434.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C10_G17_s20200401630321_e20200401639399_c20200401639440.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C10_G17_s20200410200319_e20200410209397_c20200410209436.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C10_G17_s20200410210319_e20200410219397_c20200410219434.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C10_G17_s20200410750319_e20200410759397_c20200410759454.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C10_G16_s20200462120201_e20200462129521_c20200462129575.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C10_G16_s20200470500201_e20200470509520_c20200470509584.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C10_G16_s20200481650201_e20200481659520_c20200481659579.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C10_G17_s20202500220319_e20202500229397_c20202500229428.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C10_G16_s20202570820189_e20202570829509_c20202570829544.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C10_G17_s20202640700319_e20202640709397_c20202640709430.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C10_G17_s20202870220319_e20202870229397_c20202870229436.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C10_G17_s20203521640321_e20203521649399_c20203521649440.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C10_G16_s20210030450205_e20210030459525_c20210030459595.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G17_s20193480710341_e20193480719408_c20193480719466.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G17_s20193491650341_e20193491659408_c20193491659459.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G17_s20193550320326_e20193550329392_c20193550329452.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G16_s20193571600221_e20193571609529_c20193571609593.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G17_s20193572250333_e20193572259400_c20193572259454.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G17_s20193580400334_e20193580409401_c20193580409455.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G16_s20200050600214_e20200050609522_c20200050609587.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G16_s20200060000211_e20200060009518_c20200060009581.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G17_s20200342150319_e20200342159386_c20200342159437.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G17_s20200400410319_e20200400419386_c20200400419439.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G17_s20200400620319_e20200400629386_c20200400629453.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G17_s20200400710319_e20200400719386_c20200400719438.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G17_s20200410120319_e20200410129385_c20200410129436.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G16_s20200462120201_e20200462129509_c20200462129580.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G16_s20200470500201_e20200470509509_c20200470509572.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G16_s20201280610144_e20201280619452_c20201280619506.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G16_s20201282130144_e20201282139452_c20201282139504.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G17_s20201281950321_e20201281959388_c20201281959443.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G16_s20201491000164_e20201491009472_c20201491009535.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G17_s20201790910322_e20201790919389_c20201790919454.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G17_s20202490120319_e20202490129386_c20202490129447.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G17_s20202500220319_e20202500229386_c20202500229434.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G16_s20210061350203_e20210061359511_c20210061359569.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G16_s20210062330201_e20210062339508_c20210062339588.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G16_s20210250920190_e20210250929498_c20210250929553.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C11_G17_s20210601710321_e20210601719387_c20210601719435.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C12_G17_s20193572250333_e20193572259405_c20193572259466.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C12_G17_s20193580400334_e20193580409406_c20193580409464.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C12_G16_s20193601830219_e20193601839533_c20193601839597.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C12_G16_s20200050600214_e20200050609527_c20200050609597.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C12_G17_s20200400620319_e20200400629391_c20200400629440.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C12_G17_s20200410120319_e20200410129391_c20200410129439.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C12_G16_s20200470500201_e20200470509514_c20200470509579.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C12_G17_s20200490030319_e20200490039391_c20200490039435.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M3C12_G17_s20200511815314_e20200511824386_c20200511824444.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C12_G16_s20201282130144_e20201282139458_c20201282139508.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C12_G17_s20201461800321_e20201461809394_c20201461809432.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C12_G16_s20201761750202_e20201761759516_c20201761759591.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C12_G17_s20201790910322_e20201790919395_c20201790919437.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C12_G17_s20202490120319_e20202490129391_c20202490129428.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C12_G17_s20202500220319_e20202500229391_c20202500229438.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C12_G17_s20202571700321_e20202571709393_c20202571709432.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C12_G16_s20202670820161_e20202670829475_c20202670829543.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C12_G17_s20203260750319_e20203260759391_c20203260759447.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C13_G16_s20193601150222_e20193601159541_c20193601200029.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C13_G17_s20193620640345_e20193620649423_c20193620649469.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C13_G17_s20200161800321_e20200161809399_c20200161809451.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C13_G16_s20200471930200_e20200471939520_c20200471940011.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C13_G16_s20201052040164_e20201052049484_c20201052049558.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C13_G16_s20201862350218_e20201862359538_c20201870000014.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C13_G16_s20202551520196_e20202551529516_c20202551529573.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C13_G16_s20202571730186_e20202571739506_c20202571739578.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C13_G17_s20202671050321_e20202671059399_c20202671059450.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C13_G16_s20202821040184_e20202821049504_c20202821049580.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C13_G16_s20203630630215_e20203630639535_c20203630639591.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C13_G16_s20210152300192_e20210152309512_c20210152309584.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C14_G17_s20193560830329_e20193560839396_c20193560839463.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C14_G16_s20193601200222_e20193601209530_c20193601210011.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C14_G17_s20200161800321_e20200161809388_c20200161809449.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C14_G17_s20200402030321_e20200402039388_c20200402039445.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C14_G16_s20200471930200_e20200471939508_c20200471940007.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C14_G17_s20200480750319_e20200480759386_c20200480759448.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C14_G17_s20201040340319_e20201040349386_c20201040349455.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C14_G16_s20201052040164_e20201052049472_c20201052049540.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C14_G17_s20201050110319_e20201050119386_c20201050119448.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C14_G16_s20201231830147_e20201231839455_c20201231839534.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C14_G17_s20202791310321_e20202791319387_c20202791319449.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C14_G17_s20210140410320_e20210140419386_c20210140419442.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C14_G16_s20210631410167_e20210631419475_c20210631419560.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C15_G17_s20193480820338_e20193480829411_c20193480829470.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C15_G16_s20193591720221_e20193591729535_c20193591730028.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C15_G16_s20200170510195_e20200170519509_c20200170519590.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C15_G17_s20200200630320_e20200200639392_c20200200639456.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C15_G17_s20200310750319_e20200310759392_c20200310759445.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C15_G17_s20200331510321_e20200331519393_c20200331519441.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C15_G17_s20200400420319_e20200400429391_c20200400429453.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C15_G17_s20200400510319_e20200400519391_c20200400519455.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C15_G17_s20200401800321_e20200401809393_c20200401809455.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C15_G16_s20200470500201_e20200470509514_c20200470509588.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C15_G16_s20200481650201_e20200481659515_c20200481700006.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C15_G17_s20200480750319_e20200480759391_c20200480759453.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C15_G17_s20201050110319_e20201050119391_c20201050119453.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C15_G17_s20201122000321_e20201122009393_c20201122009452.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C15_G17_s20201131550321_e20201131559393_c20201131559447.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C15_G16_s20202671130160_e20202671139474_c20202671139557.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C15_G16_s20202682130203_e20202682139516_c20202682139595.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C15_G16_s20202691300204_e20202691309517_c20202691309596.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C15_G17_s20202720610319_e20202720619391_c20202720619453.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C15_G17_s20202762140318_e20202762149391_c20202762149445.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C15_G17_s20202781700321_e20202781709393_c20202781709453.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C16_G17_s20193501000341_e20193501009419_c20193501009474.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C16_G17_s20193501300341_e20193501309419_c20193501309472.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C16_G17_s20193501800342_e20193501809420_c20193501809476.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C16_G17_s20193600950342_e20193600959420_c20193600959471.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C16_G17_s20200211740321_e20200211749400_c20200211749446.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C16_G17_s20200331510321_e20200331519399_c20200331519447.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C16_G17_s20200392010321_e20200392019399_c20200392019432.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C16_G17_s20200400720319_e20200400729397_c20200400729432.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C16_G17_s20200401710321_e20200401719399_c20200401719439.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C16_G17_s20200471920321_e20200471929399_c20200471929444.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C16_G16_s20200481650201_e20200481659520_c20200481659592.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C16_G17_s20200931840321_e20200931849399_c20200931849436.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C16_G17_s20201050110319_e20201050119397_c20201050119451.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C16_G17_s20202320420319_e20202320429397_c20202320429443.nc
# /scratch/gops/amqpfind/adomako_data/l1b_imagery_sharkfin/OR_ABI-L1b-RadF-M6C16_G17_s20202721520321_e20202721529399_c20202721529445.nc

# %%
# artifactList = [sharkfins_FD_NC]

# netcdf = []
# for CH in range(7,17):
#     channel = str(CH).zfill(2)
#     myGlob = glob.glob(op.join(artifact,'*C{}*.nc'.format(channel)))
#     netcdf += myGlob
